# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
# The code was removed by DSX for sharing.
# Out:
#   Unnamed: 0                Combined         1         2         3  4  \
# 0    get_per     ACT12339 France CSU  0.000000  0.000000  0.000000  1
# 1    get_per        ACT12340 Belgium  0.000000  0.000000  0.588235  1
# 2    get_per          ACT12340 Spain  0.222222  0.555556  0.722222  1
# 3    get_per        ACT12340 USA CSU  0.000000  0.066667  0.200000  1
# 4    get_per  ACT12688 USA Corporate  0.035714  0.178571  0.571429  1
#
#    Cluster2  Cluster3  0
# 0         1         1  0
# 1         4         3  0
# 2         6         3  0
# 3         2         1  0
# 4         2         1  0

# %%
df_data_claster_pe.where(df_data_claster_pe['Combined'] == 'EFC14835 USA CSU').dropna(subset =['Combined'])
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Combined, 1, 2, 3, 4, Cluster2, Cluster3, 0]
# Index: []

# %%
body = client_0c4374cc9ea94d83be07b65352226c15.get_object(Bucket='casa54c5781981c34a3b9e2c7062fa49bc6f',Key='CASA_ongoing_New.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_new = pd.read_csv(body)
df_data_new.head()
# Out:
#    Unnamed: 0     Study    Country  Year  Year_Period Month Exercise  \
# 0           0  EFC13889  India CSU  2017         2016   M08   Actual
# 1           1  EFC13889  India CSU  2017         2016   M09   Actual
# 2           2  EFC13889  India CSU  2017         2016   M10   Actual
# 3           3  EFC13889  India CSU  2017         2016   M11   Actual
# 4           4  EFC13889  India CSU  2017         2016   M12   Actual
#
#              Measure  Amount            Combined  Month_n  Year_n  \
# 0  Monthly Inclusion       2  EFC13889 India CSU        8    2016
# 1  Monthly Inclusion       3  EFC13889 India CSU        9    2016
# 2  Monthly Inclusion       8  EFC13889 India CSU       10    2016
# 3  Monthly Inclusion       3  EFC13889 India CSU       11    2016
# 4  Monthly Inclusion       9  EFC13889 India CSU       12    2016
#
#                   Col         Val  patient_target  period_m
# 0  EFC13889 India CSU  2016-08-31             102        15
# ...

# %%
df_data_new.where(df_data_new['Combined'] == 'EFC14835 USA CSU').dropna(subset =['Combined'])
# Out:
#       Unnamed: 0     Study  Country  Year  Year_Period Month Exercise  \
# 1146        1146  EFC14835  USA CSU  2017         2017   M03   Actual
# 1147        1147  EFC14835  USA CSU  2017         2017   M04   Actual
# 1148        1148  EFC14835  USA CSU  2017         2017   M05   Actual
# 1149        1149  EFC14835  USA CSU  2017         2017   M06   Actual
# 1150        1150  EFC14835  USA CSU  2017         2017   M07   Actual
# 4644        4644       NaN      NaN   NaN          NaN   NaN      NaN
# 4645        4645       NaN      NaN   NaN          NaN   NaN      NaN
# 4646        4646       NaN      NaN   NaN          NaN   NaN      NaN
#
#                 Measure  Amount          Combined  Month_n  Year_n  \
# 1146  Monthly Inclusion       2  EFC14835 USA CSU        3    2017
# 1147  Monthly Inclusion      15  EFC14835 USA CSU        4    2017
# 1148  Monthly Inclusion      20  EFC14835 USA CSU        5    2017
# ...

# %%
body = client_0c4374cc9ea94d83be07b65352226c15.get_object(Bucket='casa54c5781981c34a3b9e2c7062fa49bc6f',Key='CASA_PE_New.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_new = pd.read_csv(body)
df_data_new.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1     Study  Country_dim  Number of Centers  \
# 0          31           868  ACT14132   France CSU                  2
# 1          32           871  ACT14132  Germany CSU                  1
# 2          33           882  ACT14132        Japan                  3
# 3          34           915  ACT14132       Taiwan                  1
# 4          35           921  ACT14132       UK CSU                  2
#
#    Patient Target  Number of Visits     FPI/FSI     LPI/LSI  FPI/FSI Date  \
# 0               3                25  2017-08-16  2019-02-19         42963
# 1               4                25  2017-08-16  2019-02-19         42963
# 2               2                25  2017-08-16  2019-02-19         42963
# 3               4                25  2017-08-16  2019-02-19         42963
# 4               4                25  2017-08-16  2019-02-19         42963
#
#    LPI/LSI Date              Combined  Period_m
# 0         43515   ACT14132 France CSU        19
# ...

# %%
df_data_1.where(df_data_1['Combined'] == 'EFC14835 USA CSU').dropna(subset =['Combined'])
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, Study, Country_dim, Number of Centers, Patient Target, Number of Visits, FPI/FSI, LPI/LSI, FPI/FSI Date, LPI/LSI Date, Combined, Period_m]
# Index: []

# %%
body = client_0c4374cc9ea94d83be07b65352226c15.get_object(Bucket='casa54c5781981c34a3b9e2c7062fa49bc6f',Key='CASA_combo_ongoing.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_on_going = pd.read_csv(body)
df_data_on_going.head()
# Out:
#               Combined    1  2  3  4    c_rate
# 0     ACT14596 Finland  0.0  0  0  0  0.154206
# 1  ACT14596 France CSU  0.0  0  0  0  0.125604
# 2   ACT14596 Italy CSU  0.0  0  0  0  0.126659
# 3  ACT14596 Russia CSU  0.0  0  0  0  0.063389
# 4     ACT14604 Estonia  0.5  0  0  0  0.374728

# %%
df_data_on_going.where(df_data_on_going['Combined'] == 'EFC14835 USA CSU').dropna(subset =['Combined'])
# Out:
#              Combined         1         2  3  4    c_rate
# 146  EFC14835 USA CSU  0.014815  0.274074  0  0  0.606796

# %%
####merge all 3 datasets
df_data_hist_m = df_data_claster_pe[['Combined', '1', '2', '3', '4', 'Cluster2', 'Cluster3']].copy()
df_data_hist_m['c_rate'] = 1
df_data_hist_m['0'] = 0
df_data_hist_m.head()
# Out:
#                  Combined         1         2         3  4  Cluster2  \
# 0     ACT12339 France CSU  0.000000  0.000000  0.000000  1         1
# 1        ACT12340 Belgium  0.000000  0.000000  0.588235  1         4
# 2          ACT12340 Spain  0.222222  0.555556  0.722222  1         6
# 3        ACT12340 USA CSU  0.000000  0.066667  0.200000  1         2
# 4  ACT12688 USA Corporate  0.035714  0.178571  0.571429  1         2
#
#    Cluster3  c_rate  0
# 0         1       1  0
# 1         3       1  0
# 2         3       1  0
# 3         1       1  0
# 4         1       1  0

# %%
df_data_on_going_m = df_data_on_going[['Combined', '1', '2', '3', 'c_rate']].copy()
df_data_on_going_m['0'] = 0
df_data_on_going_m['4'] = 0
df_data_on_going_m['Cluster2'] = np.nan
df_data_on_going_m['Cluster3'] = np.nan
df_data_on_going_m.head()
# Out:
#               Combined    1  2  3    c_rate  0  4  Cluster2  Cluster3
# 0     ACT14596 Finland  0.0  0  0  0.154206  0  0       NaN       NaN
# 1  ACT14596 France CSU  0.0  0  0  0.125604  0  0       NaN       NaN
# 2   ACT14596 Italy CSU  0.0  0  0  0.126659  0  0       NaN       NaN
# 3  ACT14596 Russia CSU  0.0  0  0  0.063389  0  0       NaN       NaN
# 4     ACT14604 Estonia  0.5  0  0  0.374728  0  0       NaN       NaN

# %%
df_data_new_m = df_data_new[['Combined']].copy()
df_data_new_m['0'] = 0
df_data_new_m['1'] = 0
df_data_new_m['2'] = 0
df_data_new_m['3'] = 0
df_data_new_m['4'] = 0
df_data_new_m['c_rate'] = 0
df_data_new_m['Cluster2'] = np.nan
df_data_new_m['Cluster3'] = np.nan
df_data_new_m.head()
# Out:
#                Combined  0  1  2  3  4  c_rate  Cluster2  Cluster3
# 0   ACT14132 France CSU  0  0  0  0  0       0       NaN       NaN
# 1  ACT14132 Germany CSU  0  0  0  0  0       0       NaN       NaN
# 2        ACT14132 Japan  0  0  0  0  0       0       NaN       NaN
# 3       ACT14132 Taiwan  0  0  0  0  0       0       NaN       NaN
# 4       ACT14132 UK CSU  0  0  0  0  0       0       NaN       NaN

# %%
##nerge 3 data tables
frames = [df_data_new_m, df_data_on_going_m, df_data_hist_m]
df_data_all_m = pd.concat(frames)

# %%
df_data_all_m.where(df_data_all_m['Combined'] == 'EFC14835 USA CSU').dropna(subset =['Combined'])
# Out:
#      0         1         2  3  4  Cluster2  Cluster3          Combined  \
# 146  0  0.014815  0.274074  0  0       NaN       NaN  EFC14835 USA CSU
#
#        c_rate
# 146  0.606796

# %%
df_data_all_m.where((df_data_all_m['c_rate'] < 1) & (df_data_all_m['c_rate'] > 0.25)).dropna(subset=['c_rate']).head()
# Out:
#     0      1  2  3  4  Cluster2  Cluster3              Combined    c_rate
# 4   0  0.500  0  0  0       NaN       NaN      ACT14604 Estonia  0.374728
# 5   0  0.250  0  0  0       NaN       NaN  ACT14604 Germany CSU  0.250653
# 8   0  0.125  0  0  0       NaN       NaN       ACT14604 Poland  0.332558
# 10  0  0.500  0  0  0       NaN       NaN   ACT14604 Russia CSU  0.428287
# 11  0  0.200  0  0  0       NaN       NaN       ACT14604 UK CSU  0.428287

# %%
body = client_0c4374cc9ea94d83be07b65352226c15.get_object(Bucket='casa54c5781981c34a3b9e2c7062fa49bc6f',Key='df_study_corp.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_corp_att = pd.read_csv(body)
df_data_corp_att.head()
# Out:
#    Unnamed: 0     Study Country_dim  Patient Target  Number of Centers  \
# 0          13  ACC14373        Corp               8                  1
# 1         102  ACT12339        Corp              32                 14
# 2         185  ACT12340        Corp              60                 15
# 3         260  ACT12486        Corp             138                 80
# 4         274  ACT12688        Corp              28                 18
#
#    Number of Visits  FPI/FSI Date  LPI/LSI Date  Priority value Project code  \
# 0                 5         42137         42137      Priority 1     GZ385660
# 1                 8         41291         41541      Priority 2    SAR100842
# 2                22         41541         41724      Priority 1    SAR231893
# 3               NaN         42756         43018      Priority 2    SAR113244
# 4                 7         41156         41716  Not Applicable    SAR339658
#
#   Study Phase Category Therapeutic area                Area Desc  \
# ...

# %%
body = client_0c4374cc9ea94d83be07b65352226c15.get_object(Bucket='casa54c5781981c34a3b9e2c7062fa49bc6f',Key='df_study_country.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_country_att = pd.read_csv(body)
df_data_country_att.head()
# Out:
#    Unnamed: 0     Study    Country_dim  Number of Centers  Patient Target  \
# 0          87  ACT11917     Russia CSU                 12              31
# 1          88  ACT11917        Ukraine                  4              17
# 2         112  ACT12339     France CSU                  3               5
# 3         167  ACT12339  USA Corporate                 14              32
# 4         176  ACT12340        Belgium                  2              18
#
#    Number of Visits     FPI/FSI     LPI/LSI  FPI/FSI Date  LPI/LSI Date
# 0               NaN  2012-07-17  2013-03-18         41107         41351
# 1               NaN  2012-08-02  2013-03-18         41123         41351
# 2                 8  2013-03-13  2013-09-24         41346         41541
# 3                 8  2013-01-17  2013-09-24         41291         41541
# 4                22  2013-09-24  2014-03-26         41541         41724

# %%
#merging tables


df_data_att = pd.merge(df_data_country_att, df_data_corp_att, how = 'inner', on = ['Study'], suffixes=('_country', '_corp'))
df_data_att = df_data_att.rename(columns={"Country_dim_country": "Country"})

# %%
df_data_att.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1712 entries, 0 to 1711
# Data columns (total 27 columns):
# Unnamed: 0_country           1712 non-null int64
# Study                        1712 non-null object
# Country                      1712 non-null object
# Number of Centers_country    1619 non-null float64
# Patient Target_country       1618 non-null float64
# Number of Visits_country     1638 non-null float64
# FPI/FSI_country              1712 non-null object
# LPI/LSI_country              1712 non-null object
# FPI/FSI Date_country         1712 non-null int64
# LPI/LSI Date_country         1712 non-null int64
# Unnamed: 0_corp              1712 non-null int64
# Country_dim_corp             1712 non-null object
# Patient Target_corp          1712 non-null int64
# Number of Centers_corp       1712 non-null int64
# Number of Visits_corp        1638 non-null float64
# FPI/FSI Date_corp            1712 non-null int64
# LPI/LSI Date_corp            1712 non-null int64
# ...

# %%
df_data_att['Combined'] = df_data_att['Study'] + ' ' + df_data_att['Country']

# %%
df_data_att['Month_Count'] = ((df_data_att['LPI/LSI Date_country'] - df_data_att['FPI/FSI Date_country']) / 30 + 1).astype(int)
df_data_att['Month_Count'].head()
# Out:
# 0    7
# 1    9
# 2    7
# 3    7
# 4    4
# Name: Month_Count, dtype: int64

# %%
df_data_combo = pd.merge(df_data_att, df_data_all_m, how = 'inner', on = ['Combined'], suffixes=('_at', '_cl'))

# %%
df_data_combo.where(df_data_combo['Combined'] == 'EFC14835 USA CSU').dropna(subset =['Combined'])
# Out:
#      Unnamed: 0_country     Study  Country  Number of Centers_country  \
# 809               13141  EFC14835  USA CSU                         35
#
#      Patient Target_country  Number of Visits_country FPI/FSI_country  \
# 809                     135                        14      2017-03-21
#
#     LPI/LSI_country  FPI/FSI Date_country  LPI/LSI Date_country    ...     \
# 809      2017-10-13                 42815                 43021    ...
#
#              Combined Month_Count  0         1         2  3  4 Cluster2  \
# 809  EFC14835 USA CSU           7  0  0.014815  0.274074  0  0      NaN
#
#     Cluster3    c_rate
# 809      NaN  0.606796
#
# [1 rows x 37 columns]

# %%
df_data_combo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1236 entries, 0 to 1235
# Data columns (total 37 columns):
# Unnamed: 0_country           1236 non-null int64
# Study                        1236 non-null object
# Country                      1236 non-null object
# Number of Centers_country    1236 non-null float64
# Patient Target_country       1235 non-null float64
# Number of Visits_country     1187 non-null float64
# FPI/FSI_country              1236 non-null object
# LPI/LSI_country              1236 non-null object
# FPI/FSI Date_country         1236 non-null int64
# LPI/LSI Date_country         1236 non-null int64
# Unnamed: 0_corp              1236 non-null int64
# Country_dim_corp             1236 non-null object
# Patient Target_corp          1236 non-null int64
# Number of Centers_corp       1236 non-null int64
# Number of Visits_corp        1187 non-null float64
# FPI/FSI Date_corp            1236 non-null int64
# LPI/LSI Date_corp            1236 non-null int64
# ...

# %%
df_data_combo[['Combined', 'Study', 'Country', 'Number of Centers_country', 'Patient Target_country', 'Therapeutic area','Study Phase', 'Cluster2', 'Cluster3']].head(15)
# Out:
#                        Combined     Study             Country  \
# 0           ACT12339 France CSU  ACT12339          France CSU
# 1              ACT12340 Belgium  ACT12340             Belgium
# 2                ACT12340 Spain  ACT12340               Spain
# 3              ACT12340 USA CSU  ACT12340             USA CSU
# 4        ACT12688 USA Corporate  ACT12688       USA Corporate
# 5                ACT12781 Japan  ACT12781               Japan
# 6   ACT13480 Czech Republic CSU  ACT13480  Czech Republic CSU
# 7           ACT13480 France CSU  ACT13480          France CSU
# 8            ACT13480 Italy CSU  ACT13480           Italy CSU
# 9                ACT13480 Spain  ACT13480               Spain
# 10              ACT13480 Turkey  ACT13480              Turkey
# 11             ACT13480 USA CSU  ACT13480             USA CSU
# 12               ACT13710 Japan  ACT13710               Japan
# 13          ACT13739 France CSU  ACT13739          France CSU
# ...

# %%
#plt.plot(df_data_combo['Cluster2'], df_data_combo['Month_Count'], 'og')

#plt.show()
#plt.close(1)

# %%
plt.plot(df_data_combo['Cluster3'], df_data_combo[['1']], 'ro')
plt.plot(df_data_combo['Cluster3'], df_data_combo[['2']], 'bo')
plt.plot(df_data_combo['Cluster3'], df_data_combo[['3']], 'go')

plt.show()
plt.close(1)

# %%
from sklearn.preprocessing import LabelEncoder
le_y_phase = LabelEncoder()
y_phase = df_data_combo['Study Phase']
y_phase_numeric = le_y_phase.fit_transform(y_phase)
#print y_country_numeric
df_data_combo['y_phase_numeric'] = y_phase_numeric

# %%
df_data_combo_gr = df_data_combo.groupby(by=['Month_Count', 'Cluster2'], group_keys=False,as_index=False)['Combined'].count()
#print df_data_combo_gr

# %%
plt.scatter(df_data_combo_gr['Cluster2'], df_data_combo_gr['Month_Count'],s= df_data_combo_gr['Combined'])

plt.show()
plt.close(1)

# %%
df_data_combo_gr = df_data_combo.groupby(by=['y_phase_numeric', 'Cluster2'], group_keys=False,as_index=False)['Combined'].count()
#print df_data_combo_gr

# %%
plt.scatter(df_data_combo_gr['Cluster2'], df_data_combo_gr['y_phase_numeric'],s= df_data_combo_gr['Combined'])

plt.show()
plt.close(1)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_country = df_data_combo['Country']
y_country_numeric = le.fit_transform(y_country)
#print y_country_numeric
df_data_combo['y_country_numeric'] = y_country_numeric

# %%
#plt.plot(df_data_combo['Cluster2'], df_data_combo['Country'])

#plt.show()
#plt.close(1)

# %%
from sklearn.preprocessing import LabelEncoder
le_area = LabelEncoder()
y_area = df_data_combo['Therapeutic area']
y_area_numeric = le_area.fit_transform(y_area)
#print y_country_numeric
df_data_combo['y_area_numeric'] = y_area_numeric

# %%
le_prior = LabelEncoder()
y_prior = df_data_combo['Priority value']
y_prior_numeric = le_prior.fit_transform(y_prior)
#print y_country_numeric
df_data_combo['y_prior_numeric'] = y_prior_numeric

# %%
le.classes_
le_prior.classes_
# Out:
# array([nan, nan, nan, nan, nan, nan, 'LCM project', 'Not Applicable',
#        'Priority 1', 'Priority 2'], dtype=object)

# %%
df_data_combo_gr = df_data_combo.groupby(by=['y_area_numeric', 'Cluster2'], group_keys=False,as_index=False)['Combined'].count()
#print df_data_combo_gr

# %%
plt.scatter(df_data_combo_gr['Cluster2'], df_data_combo_gr['y_area_numeric'],s= df_data_combo_gr['Combined']*2)

plt.show()
plt.close(1)

# %%
df_data_combo_gr = df_data_combo.groupby(by=['y_country_numeric', 'Cluster2'], group_keys=False,as_index=False)['Combined'].count()
#print df_data_combo_gr

# %%
plt.scatter(df_data_combo_gr['Cluster2'], df_data_combo_gr['y_country_numeric'],s= df_data_combo_gr['Combined']*2)

plt.show()
plt.close(1)

# %%
#develop a model for new studies, based on historical data only

# %%
#for new studies , exclude 1 (early end) and 4 (late start)
df_data_combo_hist = df_data_combo.where((df_data_combo['c_rate'] == 1) & (df_data_combo_hist['Cluster2'] <> 1) & (df_data_combo_hist['Cluster2'] <> 4)).dropna(subset=['c_rate']).copy()
print 'hist:', df_data_combo_hist['Combined'].count()

#for 25% of studies , exclude 1 (early end)
df_data_combo_new = df_data_combo.where((df_data_combo['c_rate'] < 0.25) ).dropna(subset=['Number of Centers_country', 'Patient Target_country', 'y_country_numeric', 'y_phase_numeric', 'y_area_numeric', 'y_prior_numeric', 'Month_Count']).copy()
print 'new:', df_data_combo_new['Combined'].count()

df_data_combo_1 = df_data_combo.where((df_data_combo['c_rate'] >= 0.25) & (df_data_combo['c_rate'] < 0.5)).dropna(subset=['c_rate']).copy()
print '>=25%:', df_data_combo_1['Combined'].count()

df_data_combo_2 = df_data_combo.where((df_data_combo['c_rate'] >= 0.5) & (df_data_combo['c_rate'] < 0.75)).dropna(subset=['c_rate']).copy()
print '>=50%:', df_data_combo_2['Combined'].count()

df_data_combo_3 = df_data_combo.where((df_data_combo['c_rate'] >= 0.75) & (df_data_combo['c_rate'] < 1)).dropna(subset=['c_rate']).copy()
print '>=75%:', df_data_combo_3['Combined'].count()
# Out:
# hist: 617
# new: 352
# >=25%: 33
# >=50%: 90
# >=75%: 72

# %%
df_data_combo_3.where(df_data_combo_3['Combined'] == 'EFC14835 USA CSU').dropna(subset =['Combined'])
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0_country, Study, Country, Number of Centers_country, Patient Target_country, Number of Visits_country, FPI/FSI_country, LPI/LSI_country, FPI/FSI Date_country, LPI/LSI Date_country, Unnamed: 0_corp, Country_dim_corp, Patient Target_corp, Number of Centers_corp, Number of Visits_corp, FPI/FSI Date_corp, LPI/LSI Date_corp, Priority value, Project code, Study Phase, Category, Therapeutic area, Area Desc, Clinical indication, Clinical indication desc, FPI/FSI_corp, LPI/LSI_corp, Combined, Month_Count, 0, 1, 2, 3, 4, Cluster2, Cluster3, c_rate, y_phase_numeric, y_country_numeric, y_area_numeric, y_prior_numeric]
# Index: []
#
# [0 rows x 41 columns]

# %%
df_data_combo_new.head()
# Out:
#     Unnamed: 0_country     Study      Country  Number of Centers_country  \
# 18                 868  ACT14132   France CSU                          2
# 19                 871  ACT14132  Germany CSU                          1
# 20                 882  ACT14132        Japan                          3
# 21                 915  ACT14132       Taiwan                          1
# 22                 921  ACT14132       UK CSU                          2
#
#     Patient Target_country  Number of Visits_country FPI/FSI_country  \
# 18                       3                        25      2017-08-16
# 19                       4                        25      2017-08-16
# 20                       2                        25      2017-08-16
# 21                       4                        25      2017-08-16
# 22                       4                        25      2017-08-16
#
#    LPI/LSI_country  FPI/FSI Date_country  LPI/LSI Date_country  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import cross_val_score

#for ne wstudies , exclude 1 (early end) and 4 (late start)
X_hist = df_data_combo_hist[['Number of Centers_country', 'Patient Target_country', 'y_country_numeric', 'y_phase_numeric', 'y_area_numeric', 'y_prior_numeric', 'Month_Count']]
y_hist = df_data_combo_hist["Cluster2"]
#X_hist = df_data_combo_hist[['Number of Centers_country', 'Patient Target_country', 'y_country_numeric', 'y_phase_numeric', 'y_area_numeric', 'y_prior_numeric', 'Month_Count']]
#y_hist = df_data_combo_hist["Cluster2"]
model_hist = RandomForestClassifier(n_estimators = 100)
model_hist.fit(X_hist, y_hist)
#By default, the value is set to 0.25
scores = cross_val_score(model_hist, X_hist, y_hist, scoring='accuracy', cv=4)
print('CV Accuracy {}, Average Accuracy {}'.format(scores, scores.mean()))
# Out:
# CV Accuracy [ 0.35  0.28  0.38  0.33], Average Accuracy 0.333930180088

# %%
features = X_hist.columns
feature_importances = model_hist.feature_importances_

features_df = pd.DataFrame({'Features': features, 'Importance Score': feature_importances})
features_df.sort_values('Importance Score', inplace=True, ascending=False)

features_df.head(10)
# Out:
#                     Features  Importance Score
# 1     Patient Target_country          0.226485
# 6                Month_Count          0.213117
# 0  Number of Centers_country          0.176288
# 2          y_country_numeric          0.174642
# 4             y_area_numeric          0.084503
# 3            y_phase_numeric          0.062586
# 5            y_prior_numeric          0.062380

# %%
plt.figure(1, figsize=(7, 3))
plt.title("Feature importances")
plt.bar(range(features_df['Features'].shape[0]), features_df['Importance Score'],
       color="g",align="center")
plt.xticks(range(features_df['Features'].shape[0]), features_df['Features'].unique(),rotation=90)
#plt.xlim([-1, X_train.shape[1]])
plt.show()

# %%
features_df['Features'].shape[0]
# Out:
# 7

# %%
xPred = X_hist
#model.predict()
xPredResult = model_hist.predict(xPred)
df_data_combo_hist['Cluster2_Predict'] = xPredResult

# %%
from sklearn.metrics import confusion_matrix
import itertools
import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.cross_validation import train_test_split


# Split the data into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X_hist, y_hist, random_state=0)

# Run classifier, using a model that is too regularized (C too low) to see
# the impact on the results
classifier = RandomForestClassifier(n_estimators = 100)
#model_hist.fit(X_hist, y_hist)

#classifier = svm.SVC(kernel='linear', C=0.01)
y_pred = classifier.fit(X_train, y_train).predict(X_test)

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    # Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=y_hist.sort_values().unique(),
                      title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=y_hist.sort_values().unique(), normalize=True,
                      title='Normalized confusion matrix (new)')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[16  2 11  4  1]
#  [ 0  8  0  2  4]
#  [15  1 28 11  1]
#  [ 6  2 10 11  3]
#  [ 3  2  4  4  6]]
# Normalized confusion matrix
# [[ 0.47  0.06  0.32  0.12  0.03]
#  [ 0.    0.57  0.    0.14  0.29]
#  [ 0.27  0.02  0.5   0.2   0.02]
#  [ 0.19  0.06  0.31  0.34  0.09]
#  [ 0.16  0.11  0.21  0.21  0.32]]

# %%
X_test
# Out:
#       Number of Centers_country  Patient Target_country  y_country_numeric  \
# 161                           3                       3                 62
# 1007                          2                      20                 44
# 367                           1                      15                  4
# 431                           5                      47                 39
# 294                           8                      29                 57
# 1235                          2                      14                  4
# 611                           8                      10                 53
# 599                           3                       5                  4
# 927                           3                      36                 16
# 908                           4                       6                 46
# 279                          32                     317                 27
# ...

# %%
df_data_combo_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352 entries, 18 to 1234
# Data columns (total 41 columns):
# Unnamed: 0_country           352 non-null float64
# Study                        352 non-null object
# Country                      352 non-null object
# Number of Centers_country    352 non-null float64
# Patient Target_country       352 non-null float64
# Number of Visits_country     303 non-null float64
# FPI/FSI_country              352 non-null object
# LPI/LSI_country              352 non-null object
# FPI/FSI Date_country         352 non-null float64
# LPI/LSI Date_country         352 non-null float64
# Unnamed: 0_corp              352 non-null float64
# Country_dim_corp             352 non-null object
# Patient Target_corp          352 non-null float64
# Number of Centers_corp       352 non-null float64
# Number of Visits_corp        303 non-null float64
# FPI/FSI Date_corp            352 non-null float64
# LPI/LSI Date_corp            352 non-null float64
# ...

# %%
X_new = df_data_combo_new[['Number of Centers_country', 'Patient Target_country', 'y_country_numeric', 'y_phase_numeric', 'y_area_numeric', 'y_prior_numeric', 'Month_Count']].dropna()
xPredResult = model_hist.predict(X_new)
#df_data_combo_new['Cluster2_Predict'] = xPredResult

# %%
X_1_features = ['1', 'Number of Centers_country', 'Patient Target_country', 'y_country_numeric', 'y_phase_numeric', 'y_area_numeric', 'y_prior_numeric', 'Month_Count']
#X_1 = df_data_combo_hist[X_1_features]
X_1 = df_data_combo_hist[X_1_features]
#y = df_data_combo_hist["Cluster2"]
y = df_data_combo_hist["Cluster2"]

model_1 = RandomForestClassifier(n_estimators = 100)
model_1.fit(X_1, y)

scores = cross_val_score(model_1, X_1, y, scoring='accuracy', cv=4)
print('CV Accuracy {}, Average Accuracy {}'.format(scores, scores.mean()))
# Out:
# CV Accuracy [ 0.59  0.6   0.6   0.5 ], Average Accuracy 0.573544129284

# %%
features = X_1.columns
feature_importances = model_1.feature_importances_

features_df = pd.DataFrame({'Features': features, 'Importance Score': feature_importances})
features_df.sort_values('Importance Score', inplace=True, ascending=False)

features_df.head(10)
# Out:
#                     Features  Importance Score
# 0                          1          0.353251
# 2     Patient Target_country          0.138763
# 7                Month_Count          0.135972
# 1  Number of Centers_country          0.115460
# 3          y_country_numeric          0.104724
# 5             y_area_numeric          0.060972
# 6            y_prior_numeric          0.048145
# 4            y_phase_numeric          0.042713

# %%
xPredResult = model_1.predict(df_data_combo_1[X_1_features])
df_data_combo_1['Cluster2_Predict'] = xPredResult

# %%
X_2_features = ['2', '1', 'Number of Centers_country', 'Patient Target_country', 'y_country_numeric', 'y_phase_numeric', 'y_area_numeric', 'y_prior_numeric', 'Month_Count']
X_2 = df_data_combo_hist[X_2_features]
y = df_data_combo_hist["Cluster2"]

model_2 = RandomForestClassifier(n_estimators = 100)
model_2.fit(X_2, y)

scores = cross_val_score(model_2, X_2, y, scoring='accuracy',cv=4)
print('CV Accuracy {}, Average Accuracy {}'.format(scores, scores.mean()))
# Out:
# CV Accuracy [ 0.82  0.85  0.84  0.75], Average Accuracy 0.815055406327

# %%
features = X_2.columns
feature_importances = model_2.feature_importances_

features_df = pd.DataFrame({'Features': features, 'Importance Score': feature_importances})
features_df.sort_values('Importance Score', inplace=True, ascending=False)

features_df.head(10)
# Out:
#                     Features  Importance Score
# 0                          2          0.389376
# 1                          1          0.298428
# 3     Patient Target_country          0.072631
# 8                Month_Count          0.067332
# 2  Number of Centers_country          0.052913
# 4          y_country_numeric          0.042282
# 6             y_area_numeric          0.029380
# 7            y_prior_numeric          0.029081
# 5            y_phase_numeric          0.018578

# %%
xPredResult = model_2.predict(df_data_combo_2[X_2_features])
df_data_combo_2['Cluster2_Predict'] = xPredResult

# %%
from sklearn.metrics import confusion_matrix
import itertools
import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.cross_validation import train_test_split

# Split the data into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X_2, y, random_state=0)

# Run classifier, using a model that is too regularized (C too low) to see
# the impact on the results
classifier = RandomForestClassifier(n_estimators = 100)
#model_hist.fit(X_hist, y_hist)

#classifier = svm.SVC(kernel='linear', C=0.01)
y_pred = classifier.fit(X_train, y_train).predict(X_test)

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    # Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=y_hist.sort_values().unique(),
                      title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=y_hist.sort_values().unique(), normalize=True,
                      title='Normalized confusion matrix (>25%)')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[28  0  6  0  0]
#  [ 0 13  0  0  1]
#  [ 1  0 51  3  1]
#  [ 0  0  5 26  1]
#  [ 0  1  2  3 13]]
# Normalized confusion matrix
# [[ 0.82  0.    0.18  0.    0.  ]
#  [ 0.    0.93  0.    0.    0.07]
#  [ 0.02  0.    0.91  0.05  0.02]
#  [ 0.    0.    0.16  0.81  0.03]
#  [ 0.    0.05  0.11  0.16  0.68]]

# %%
X_3_features = ['3', '2', '1', 'Number of Centers_country', 'Patient Target_country', 'y_country_numeric', 'y_phase_numeric', 'y_area_numeric', 'y_prior_numeric', 'Month_Count']
X_3 = df_data_combo_hist[X_3_features]
y = df_data_combo_hist["Cluster2"]

model_3 = RandomForestClassifier(n_estimators = 100)
model_3.fit(X_3, y)

scores = cross_val_score(model_3, X_3, y, scoring='accuracy', cv=4)
print('CV Accuracy {}, Average Accuracy {}'.format(scores, scores.mean()))
# Out:
# CV Accuracy [ 0.92  0.94  0.91  0.93], Average Accuracy 0.92706189025

# %%
features = X_3.columns
feature_importances = model_3.feature_importances_

features_df = pd.DataFrame({'Features': features, 'Importance Score': feature_importances})
features_df.sort_values('Importance Score', inplace=True, ascending=False)

features_df.head(10)
# Out:
#                     Features  Importance Score
# 0                          3          0.276257
# 2                          1          0.270584
# 1                          2          0.262007
# 4     Patient Target_country          0.046349
# 9                Month_Count          0.043512
# 3  Number of Centers_country          0.035047
# 5          y_country_numeric          0.024304
# 8            y_prior_numeric          0.016316
# 7             y_area_numeric          0.015413
# 6            y_phase_numeric          0.010212

# %%
plt.figure(1, figsize=(7, 3))
plt.title("Feature importances")
plt.bar(range(features_df['Features'].shape[0]), features_df['Importance Score'],
       color="g",align="center")
plt.xticks(range(features_df['Features'].shape[0]), features_df['Features'].unique(),rotation=90)
#plt.xlim([-1, X_train.shape[1]])
plt.show()

# %%
#Image(graph.create_png())

# %%
xPredResult = model_3.predict(df_data_combo_3[X_3_features])
df_data_combo_3['Cluster2_Predict'] = xPredResult

# %%
from sklearn.metrics import confusion_matrix
import itertools
import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.cross_validation import train_test_split

# Split the data into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X_3, y, random_state=0)

# Run classifier, using a model that is too regularized (C too low) to see
# the impact on the results
classifier = RandomForestClassifier(n_estimators = 100)
#model_hist.fit(X_hist, y_hist)

#classifier = svm.SVC(kernel='linear', C=0.01)
y_pred = classifier.fit(X_train, y_train).predict(X_test)

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    # Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=y_hist.sort_values().unique(),
                      title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=y_hist.sort_values().unique(), normalize=True,
                      title='Normalized confusion matrix >75%')

plt.show()
# Out:
# Confusion matrix, without normalization
# [[29  0  5  0  0]
#  [ 0 12  0  0  2]
#  [ 1  0 53  2  0]
#  [ 0  0  2 29  1]
#  [ 0  0  0  1 18]]
# Normalized confusion matrix
# [[ 0.85  0.    0.15  0.    0.  ]
#  [ 0.    0.86  0.    0.    0.14]
#  [ 0.02  0.    0.95  0.04  0.  ]
#  [ 0.    0.    0.06  0.91  0.03]
#  [ 0.    0.    0.    0.05  0.95]]

# %%
##nerge 3 data tables
#frames = [df_data_new_m, df_data_on_going_m, df_data_hist_m]
#df_data_all_m = pd.concat(frames)

df_data_combo_predicted = pd.concat([df_data_combo_hist,df_data_combo_new,df_data_combo_1,df_data_combo_2,df_data_combo_3])

# %%
df_data_combo_predicted
# Out:
#       0         1         2         3  4                       Area Desc  \
# 2     0  0.222222  0.555556  0.722222  1              Respiratory system
# 3     0  0.000000  0.066667  0.200000  1              Respiratory system
# 4     0  0.035714  0.178571  0.571429  1                  Nervous System
# 5     0  0.250000  0.437500  0.656250  1  Anti-cancer & Immunomodulators
# 6     0  0.312500  0.500000  0.750000  1                   Ophthalmology
# 7     0  0.666667  1.000000  1.000000  1                   Ophthalmology
# 8     0  0.600000  0.800000  0.800000  1                   Ophthalmology
# 9     0  0.571429  0.857143  0.857143  1                   Ophthalmology
# 10    0  0.062500  0.250000  0.375000  1                   Ophthalmology
# 11    0  0.100000  0.400000  0.500000  1                   Ophthalmology
# 12    0  0.142857  0.285714  0.785714  1  Anti-cancer & Immunomodulators
# 14    0  1.000000  1.000000  1.000000  1         Alimentary & Metabolism
# ...

# %%
# The code was removed by DSX for sharing.

# %%
from ibm_botocore.client import Config
import ibm_boto3
cos = ibm_boto3.client(service_name='s3',
    ibm_api_key_id=credentials['IBM_API_KEY_ID'],
    ibm_service_instance_id=credentials['IAM_SERVICE_ID'],
    ibm_auth_endpoint=credentials['IBM_AUTH_ENDPOINT'],
    config=Config(signature_version='oauth'),
    endpoint_url=credentials['ENDPOINT'])

# %%
from ibm_botocore.client import Config
import ibm_boto3
def upload_file_cos(credentials,local_file_name,key):  
    cos = ibm_boto3.client(service_name='s3',
    ibm_api_key_id=credentials['IBM_API_KEY_ID'],
    ibm_service_instance_id=credentials['IAM_SERVICE_ID'],
    ibm_auth_endpoint=credentials['IBM_AUTH_ENDPOINT'],
    config=Config(signature_version='oauth'),
    endpoint_url=credentials['ENDPOINT'])
    try:
        res=cos.upload_file(Filename=local_file_name, Bucket=credentials['BUCKET'],Key=key)
    except Exception as e:
        print(Exception, e)
    else:
        print('File Uploaded')

# %%
df_data_combo_predicted.to_csv('CASA_combo_with_classes.csv',index=True)
upload_file_cos(credentials,'CASA_combo_with_classes.csv','CASA_combo_with_classes.csv')
# Out:
# File Uploaded

# %%
df_data_combo_predicted.where(df_data_combo_predicted['Combined'] == 'TED14147 France CSU').dropna(subset =['Combined'])
# Out:
#       0         1         2  3  4                       Area Desc Category  \
# 1228  0  0.069767  0.116279  0  0  Anti-cancer & Immunomodulators        G
#
#      Clinical indication Clinical indication desc  Cluster2       ...         \
# 1228                 NaN                      NaN       NaN       ...
#
#          Study  Study Phase Therapeutic area Unnamed: 0_corp  \
# 1228  TED14147            I             TA/L           32452
#
#      Unnamed: 0_country    c_rate  y_area_numeric y_country_numeric  \
# 1228              32462  0.604126              11                18
#
#      y_phase_numeric  y_prior_numeric
# 1228               0                9
#
# [1 rows x 42 columns]

# %%
#X = df_data_combo[['Number of Centers_country', 'Patient Target_country', 'y_country_numeric', 'y_phase_numeric', 'y_area_numeric', 'y_prior_numeric','Month_Count']]

scores = cross_val_score(model, X, y, scoring='accuracy')
print('CV Accuracy {}, Average Accuracy {}'.format(scores, scores.mean()))

for n_trees in range(1, 100, 10):
    model =  RandomForestClassifier(n_estimators = n_trees)
    scores = cross_val_score(model, X, y, scoring='accuracy')
    print('n trees: {}, CV Accuracy {}, Average Accuracy {}'.format(n_trees, scores, scores.mean()))
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-1057-f78e9417d8d6> in <module>()
#       2 #X = df_data_combo[['Number of Centers_country', 'Patient Target_country', 'y_country_numeric', 'y_phase_numeric', 'y_area_numeric', 'y_prior_numeric','Month_Count']]
#       3
# ----> 4 scores = cross_val_score(model, X, y, scoring='accuracy')
#       5 print('CV Accuracy {}, Average Accuracy {}'.format(scores, scores.mean()))
#       6
#
# /usr/local/src/bluemix_jupyter_bundle.v83/notebook/lib/python2.7/site-packages/sklearn/cross_validation.pyc in cross_val_score(estimator, X, y, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#    1420         Array of scores of the estimator for each run of the cross validation.
#    1421     """
# -> 1422     X, y = indexable(X, y)
#    1423
#    1424     cv = check_cv(cv, X, y, classifier=is_classifier(estimator))
#
# ...

# %%
#X = df_data_combo[['Number of Centers_country', 'Patient Target_country', 'y_country_numeric', 'y_phase_numeric', 'y_area_numeric', 'y_prior_numeric','Month_Count']]

scores = cross_val_score(model_1, X, y, scoring='accuracy')
print('CV Accuracy {}, Average Accuracy {}'.format(scores, scores.mean()))

for n_trees in range(1, 100, 10):
    model_1 =  RandomForestClassifier(n_estimators = n_trees)
    scores = cross_val_score(model, X, y, scoring='accuracy')
    print('n trees: {}, CV Accuracy {}, Average Accuracy {}'.format(n_trees, scores, scores.mean()))

# %%
from sklearn.cross_validation import cross_val_score

#X = df_data_combo[['Number of Centers_country', 'Patient Target_country', 'y_country_numeric', 'y_phase_numeric', 'y_area_numeric', 'y_prior_numeric','Month_Count']]

scores = cross_val_score(model, X, y, scoring='accuracy')
print('CV Accuracy {}, Average Accuracy {}'.format(scores, scores.mean()))

for n_trees in range(1, 100, 10):
    model =  RandomForestClassifier(n_estimators = n_trees)
    scores = cross_val_score(model, X, y, scoring='accuracy')
    print('n trees: {}, CV Accuracy {}, Average Accuracy {}'.format(n_trees, scores, scores.mean()))

# %%
##predict new studies

#xPredResult = model.predict(xPred)

# %%
##identify list of 
#new studies
#studies 1
#studies 2
#studies 3
